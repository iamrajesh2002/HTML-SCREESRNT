# %% [markdown]
# <a href="https://colab.research.google.com/github/iamrajesh2002/HTML-SCREESRNT/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("python")
# Out:
# python
